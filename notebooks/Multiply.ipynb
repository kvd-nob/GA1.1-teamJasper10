# %%
def multiply(a,b):
    x = a * b
    return x

# %%
def square (a,b):
    return multiply(a, b) * multiply(a, b)

# %%
print(multiply(5,8))
# Out:
# 40

# %%
print(square(5,8))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 print(square(5,8))
#
# Cell In[2], line 2, in square(a, b)
#       1 def square (a,b):
# ----> 2     return multiply(a, b) * multiply(a, b)
#
# NameError: name 'multiply' is not defined
