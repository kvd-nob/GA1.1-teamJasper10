# %%
def subtract(x,y):
    ans = x - y
    return ans

# %%
print(subtract(5, 4))

# %%
print(subtract(10, 3))
print(subtract(7, 2))

# %%
def distance_from_zero(x):
    if x < 0:
        return -x
    else:
        return x
